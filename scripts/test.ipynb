# %%
resources =[
['aws_autoscaling_group'],
['aws_cloudtrail'],
['aws_cloudwatch_log_group',
'aws_cloudwatch_log_resource_policy',
'aws_cloudwatch_log_subscription_filter'],
['aws_db_instance',
'aws_db_parameter_group',
'aws_db_subnet_group'],
['aws_iam_access_key',
'aws_iam_instance_profile',
'aws_iam_policy',
'aws_iam_role',
'aws_iam_role_policy',
'aws_iam_role_policy_attachment',
'aws_iam_service_linked_role',
'aws_iam_user',
'aws_iam_user_policy'],
['aws_kms_alias',
'aws_kms_grant',
'aws_kms_key'],
['aws_s3_bucket',
'aws_s3_bucket_lifecycle_configuration',
'aws_s3_bucket_logging',
'aws_s3_bucket_notification',
'aws_s3_bucket_ownership_controls',
'aws_s3_bucket_policy',
'aws_s3_bucket_public_access_block',
'aws_s3_bucket_server_side_encryption_configuration',
'aws_s3_bucket_versioning'],
['aws_secretsmanager_secret',
'aws_secretsmanager_secret_version'],
['aws_sns_topic',
'aws_sns_topic_policy',
'aws_sns_topic_subscription'],
['aws_sqs_queue',
'aws_sqs_queue_policy'],
['aws_vpc',
'aws_security_group',
'aws_subnet',
'aws_vpc_ipv4_cidr_block_association',
'aws_vpc_peering_connection',
'aws_default_route_table',
'aws_eip',
'aws_internet_gateway',
'aws_nat_gateway',
'aws_route',
'aws_main_route_table_association',
'aws_route_table',
'aws_flow_log'],
['aws_elasticsearch_domain'],
['aws_route53_zone'],
['aws_key_pair'],
['aws_wafv2_web_acl'],
['aws_launch_template'],

]
resources = [
['aws_key_pair'] ,
['aws_wafv2_web_acl'],
['aws_autoscaling_group'] ,
['aws_cloudtrail'] ,
['aws_elasticsearch_domain'] ,
['aws_launch_template'] ,
['aws_route53_zone'] ,
['aws_secretsmanager_secret', 'aws_secretsmanager_secret_version'] ,
['aws_sqs_queue', 'aws_sqs_queue_policy'] ,
['aws_sns_topic', 'aws_sns_topic_policy', 'aws_sns_topic_subscription'] ,
['aws_kms_alias', 'aws_kms_grant', 'aws_kms_key'] ,
['aws_db_instance', 'aws_db_parameter_group', 'aws_db_subnet_group'] ,
['aws_cloudwatch_log_group', 'aws_cloudwatch_log_resource_policy', 'aws_cloudwatch_log_subscription_filter'] ,
['aws_iam_access_key', 'aws_iam_instance_profile', 'aws_iam_policy', 'aws_iam_role', 'aws_iam_role_policy', 'aws_iam_role_policy_attachment', 'aws_iam_service_linked_role', 'aws_iam_user', 'aws_iam_user_policy'] ,
['aws_s3_bucket', 'aws_s3_bucket_lifecycle_configuration', 'aws_s3_bucket_logging', 'aws_s3_bucket_notification', 'aws_s3_bucket_ownership_controls', 'aws_s3_bucket_policy', 'aws_s3_bucket_public_access_block', 'aws_s3_bucket_server_side_encryption_configuration', 'aws_s3_bucket_versioning'] ,
['aws_vpc', 'aws_security_group', 'aws_subnet', 'aws_vpc_ipv4_cidr_block_association', 'aws_vpc_peering_connection', 'aws_default_route_table', 'aws_eip', 'aws_internet_gateway', 'aws_nat_gateway', 'aws_route', 'aws_main_route_table_association', 'aws_route_table', 'aws_flow_log']
]

# %%
# sort list
resources.sort()
for resource in resources:
    print(resource,",")
# Out:
# ['aws_autoscaling_group'] ,
# ['aws_cloudtrail'] ,
# ['aws_cloudwatch_log_group', 'aws_cloudwatch_log_resource_policy', 'aws_cloudwatch_log_subscription_filter'] ,
# ['aws_db_instance', 'aws_db_parameter_group', 'aws_db_subnet_group'] ,
# ['aws_elasticsearch_domain'] ,
# ['aws_iam_access_key', 'aws_iam_instance_profile', 'aws_iam_policy', 'aws_iam_role', 'aws_iam_role_policy', 'aws_iam_role_policy_attachment', 'aws_iam_service_linked_role', 'aws_iam_user', 'aws_iam_user_policy'] ,
# ['aws_key_pair'] ,
# ['aws_kms_alias', 'aws_kms_grant', 'aws_kms_key'] ,
# ['aws_launch_template'] ,
# ['aws_route53_zone'] ,
# ['aws_s3_bucket', 'aws_s3_bucket_lifecycle_configuration', 'aws_s3_bucket_logging', 'aws_s3_bucket_notification', 'aws_s3_bucket_ownership_controls', 'aws_s3_bucket_policy', 'aws_s3_bucket_public_access_block', 'aws_s3_bucket_server_side_encryption_configuration', 'aws_s3_bucket_versioning'] ,
# ['aws_secretsmanager_secret', 'aws_secretsmanager_secret_version'] ,
# ...
